# %%
#from sklearn.preprocessing import StandardScaler 
#scaler= StandardScaler()
#X_scaled=scaler.fit_transform(X)

# %%
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

from statsmodels.graphics.api import qqplot

# %%
dta= pd.read_csv(r"D:\ineuron\MachineLearningFiles\MLAlgos\TimeSeries\ML11 4\sunspots.csv")
dta.head(10)
# Out:
#    YEAR  SUNACTIVITY
# 0  1700          5.0
# 1  1701         11.0
# 2  1702         16.0
# 3  1703         23.0
# 4  1704         36.0
# 5  1705         58.0
# 6  1706         29.0
# 7  1707         20.0
# 8  1708         10.0
# 9  1709          8.0

# %%
dta.index = pd.Index(sm.tsa.datetools.dates_from_range('1700', '2008'))
del dta["YEAR"]

# %%
dta
# Out:
#             SUNACTIVITY
# 1700-12-31          5.0
# 1701-12-31         11.0
# 1702-12-31         16.0
# 1703-12-31         23.0
# 1704-12-31         36.0
# ...                 ...
# 2004-12-31         40.4
# 2005-12-31         29.8
# 2006-12-31         15.2
# 2007-12-31          7.5
# 2008-12-31          2.9
#
# [309 rows x 1 columns]

# %%
"""" from sklearn.preprocessing import StandardScaler 
scaler= StandardScaler()
X_scaled=scaler.fit_transform(dta)

test=pd.DataFrame(X_scaled,columns=["col"])
type(test)

# %matplotlib inline
test.plot(figsize=(12,8));

from pandas.plotting import autocorrelation_plot
autocorrelation_plot(test["col"])
plt.show() """"
# Out:
#   File "<ipython-input-16-365860d3ef72>", line 13
#     plt.show() """"
#
# ^
# SyntaxError: EOL while scanning string literal

# %%
sm.stats.durbin_watson(dta)
# Out:
# array([0.13952893])

# %%
#Positive serial correlation is associated with DW values below 2 and negative serial correlation with DW values above 2.
#2 Not Corelated

#0.13952893 strong corelation

# %%
# show plots in the notebook
# %matplotlib inline
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(dta.values.squeeze(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(dta, lags=40, ax=ax2)

# %%
#Auto Corelation - Q 
#Partial Corelation  - P

# %%
from pandas.plotting import autocorrelation_plot
# show plots in the notebook
# %matplotlib inline
dta['SUNACTIVITY_2'] = dta['SUNACTIVITY']
dta['SUNACTIVITY_2'] = (dta['SUNACTIVITY_2'] - dta['SUNACTIVITY_2'].mean()) / (dta['SUNACTIVITY_2'].std())
#Graph with standardised Dataset
plt.acorr(dta['SUNACTIVITY_2'],maxlags = len(dta['SUNACTIVITY_2']) -1, linestyle = "solid", usevlines = False, marker='')
plt.show()
#Original Dataset
autocorrelation_plot(dta['SUNACTIVITY'])
plt.show()

# %%
#Modelling the data

# %%
arma_mod20=sm.tsa.ARMA(dta["SUNACTIVITY"],(3,3)).fit()
print(arma_mod20.params)
# Out:
# C:\Users\nanda\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency A-DEC will be used.
#   warnings.warn('No frequency information was'
# const                48.865561
# ar.L1.SUNACTIVITY     2.546067
# ar.L2.SUNACTIVITY    -2.441391
# ar.L3.SUNACTIVITY     0.869944
# ma.L1.SUNACTIVITY    -1.411676
# ma.L2.SUNACTIVITY     0.431190
# ma.L3.SUNACTIVITY     0.159177
# dtype: float64

# %%
print(arma_mod20.aic, arma_mod20.bic, arma_mod20.hqic)
# Out:
# 2575.695644921477 2605.5623751366593 2587.6364206119692

# %%
#aic ,bic,hqic should be lowest we would select that p,q value

# %%
sm.stats.durbin_watson(arma_mod20.resid.values)
# Out:
# 1.949412843547897

# %%
#1.949412843547897 no auto corelation

# %%
# show plots in the notebook
# %matplotlib inline
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
ax = arma_mod20.resid.plot(ax=ax);

# %%
resid20 = arma_mod20.resid
stats.normaltest(resid20)
# Out:
# NormaltestResult(statistic=39.70678096162276, pvalue=2.3866133582710184e-09)

# %%
# show plots in the notebook
# %matplotlib inline
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
fig = qqplot(resid20, line='q', ax=ax, fit=True)

# %%
# %matplotlib inline
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(resid20.values.squeeze(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(resid20, lags=40, ax=ax2)

# %%
r,q,p = sm.tsa.acf(resid20.values.squeeze(), qstat=True)
data = np.c_[range(1,41), r[1:], q, p]
table = pd.DataFrame(data, columns=['lag', "AC", "Q", "Prob(>Q)"])
print(table.set_index('lag'))
# Out:
#             AC          Q  Prob(>Q)
# lag
# 1.0   0.009127   0.025989  0.871926
# 2.0   0.020315   0.155179  0.925344
# 3.0  -0.108075   3.823359  0.281181
# 4.0   0.065248   5.164745  0.270807
# 5.0   0.048993   5.923521  0.313732
# 6.0   0.038359   6.390187  0.380929
# 7.0  -0.021621   6.538940  0.478407
# 8.0  -0.135980  12.442347  0.132532
# 9.0   0.046138  13.124237  0.157065
# 10.0  0.072939  14.834143  0.138227
# 11.0  0.072908  16.548305  0.121965
# 12.0 -0.001448  16.548984  0.167365
# 13.0 -0.108489  20.370154  0.086357
# 14.0 -0.029224  20.648372  0.110989
# 15.0 -0.012019  20.695592  0.146840
# 16.0  0.119791  25.402140  0.063043
# 17.0  0.069779  27.004599  0.058000
# 18.0 -0.061315  28.246117  0.058407
# 19.0 -0.007323  28.263889  0.078480
# 20.0 -0.100585  31.628146  0.047425
# 21.0 -0.002836  31.630829  0.063781
# 22.0  0.054309  32.618413  0.067447
# 23.0  0.058679  33.775354  0.068477
# 24.0 -0.086022  36.270507  0.051657
# 25.0  0.021361  36.424902  0.065395
# ...

# %%
predict_sunspots20 = arma_mod20.predict('1950', '2012')
print(predict_sunspots20)
# Out:
# 1950-12-31    105.508256
# 1951-12-31     41.167538
# 1952-12-31     44.777713
# 1953-12-31     12.474935
# 1954-12-31     16.857851
#                  ...
# 2008-12-31     23.192933
# 2009-12-31     25.991069
# 2010-12-31     56.294023
# 2011-12-31     80.406869
# 2012-12-31     91.136532
# Freq: A-DEC, Length: 63, dtype: float64

# %%
ax = dta.loc['1950':].plot(figsize=(12,8))
ax = predict_sunspots20.plot(ax=ax, style='r--', label='Dynamic Prediction');
ax.legend();
ax.axis((-20.0, 38.0, -4.0, 200.0));

# %%
predict_sunspots20 = arma_mod20.predict('2008', '2012')
print(predict_sunspots20)
# Out:
# 2008-12-31    23.192933
# 2009-12-31    25.991069
# 2010-12-31    56.294023
# 2011-12-31    80.406869
# 2012-12-31    91.136532
# Freq: A-DEC, dtype: float64

# %%
ax = dta.loc['2008':].plot(figsize=(12,8))
ax = predict_sunspots20.plot(ax=ax, style='r--', label='Dynamic Prediction');
ax.legend();
#ax.axis((-20.0, 38.0, -4.0, 200.0));

# %%
#Calculate Forecast Errors

# %%
def mean_forecast_err(y, yhat):
    return y.sub(yhat).mean()

def mean_absolute_err(y, yhat):
    return np.mean((np.abs(y.sub(yhat).mean()) / yhat)) # or percent error = * 100

# %%
print("MFE = ", mean_forecast_err(dta.SUNACTIVITY, predict_sunspots20))
print("MAE = ", mean_absolute_err(dta.SUNACTIVITY, predict_sunspots20))
# Out:
# MFE =  -20.29293337403176
# MAE =  0.49825039339965

# %% [markdown]
# For MFE > 0, models tends to under-forecast. However, as long as the tracking signal is between –4 and 4, we assume the model is working correctly. The measure of MAE being small would indicate a pretty good fit.

# %%
#DataSet 2

# %%
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

from statsmodels.graphics.api import qqplot
# %matplotlib inline

# %%
female_birthrate=pd.read_csv(r"D:\ineuron\MachineLearningFiles\MLAlgos\TimeSeries\timeSeries\daily-total-female-births-CA.csv")
female_birthrate
# Out:
#            date  births
# 0    1959-01-01      35
# 1    1959-01-02      32
# 2    1959-01-03      30
# 3    1959-01-04      31
# 4    1959-01-05      44
# ..          ...     ...
# 360  1959-12-27      37
# 361  1959-12-28      52
# 362  1959-12-29      48
# 363  1959-12-30      55
# 364  1959-12-31      50
#
# [365 rows x 2 columns]

# %%
birth_data=pd.read_csv(r"D:\ineuron\MachineLearningFiles\MLAlgos\TimeSeries\timeSeries\daily-total-female-births-CA.csv", index_col=[0], parse_dates=[0])
birth_data
# Out:
#             births
# date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44
# ...            ...
# 1959-12-27      37
# 1959-12-28      52
# 1959-12-29      48
# 1959-12-30      55
# 1959-12-31      50
#
# [365 rows x 1 columns]

# %%
birth_data.describe()
# Out:
#            births
# count  365.000000
# mean    41.980822
# std      7.348257
# min     23.000000
# 25%     37.000000
# 50%     42.000000
# 75%     46.000000
# max     73.000000

# %%
birth_data.plot()

# %%
##almost a stationary series

# %%
# also called as smoothing
moving_average_birth=birth_data.rolling(window=20).mean()  # window: This is the number of observations used for calculating the statistic.

# %%
moving_average_birth
# Out:
#             births
# date
# 1959-01-01     NaN
# 1959-01-02     NaN
# 1959-01-03     NaN
# 1959-01-04     NaN
# 1959-01-05     NaN
# ...            ...
# 1959-12-27   42.10
# 1959-12-28   42.25
# 1959-12-29   42.50
# 1959-12-30   43.10
# 1959-12-31   43.90
#
# [365 rows x 1 columns]

# %%
moving_average_birth.plot()

# %%
sm.stats.durbin_watson(birth_data)
# Out:
# array([0.04624491])

# %%
#Very less i.e. near to 0 thus it has very less corerlation ,or data is staionary

# %%
# show plots in the notebook
# %matplotlib inline
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(birth_data.values.squeeze(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(birth_data, lags=40, ax=ax2)

# %%
training_data=birth_data[0:320]
test_data=birth_data[320:]

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
arima= ARIMA(training_data,order=(2,1,3))
# Out:
# C:\Users\nanda\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\nanda\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'

# %%
model=arima.fit()

# %%
model.aic
# Out:
# 2164.7000221312232

# %%
pred= model.forecast(steps=45)[0]

# %%
pred
# Out:
# array([43.11701662, 44.26298465, 43.64708402, 43.03636536, 44.07963011,
#        43.97590078, 43.1081374 , 43.84704877, 44.19531047, 43.30177036,
#        43.63324918, 44.28710442, 43.56585549, 43.49086109, 44.26330562,
#        43.84257669, 43.44849685, 44.15854976, 44.08109867, 43.50867436,
#        44.01892386, 44.2472283 , 43.65164634, 43.89023274, 44.32791434,
#        43.84333193, 43.80828873, 44.33049063, 44.0449748 , 43.79295442,
#        44.2777034 , 44.22218139, 43.84657986, 44.20028724, 44.35151774,
#        43.95643179, 44.12908142, 44.42366792, 44.09992959, 44.08844285,
#        44.44305669, 44.25110295, 44.09214193, 44.424608  , 44.38669131])

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(test_data,pred))
# Out:
# 6.61299144982713

# %%
#Use Auto ARIMA

# %%
from pmdarima import auto_arima

# %%
auto_arima(birth_data["births"],start_p=1,start_q=2,
           max_p=3,max_q=3,m=12,
          start_P=12,seasonal=True,
          d=None,D=1,trace= True,
          )
# Out:
#   File "<ipython-input-137-239c3b43ddfa>", line 3
#     start_p=12,seasonal=True,)
#     ^
# SyntaxError: keyword argument repeated
